# %%
import numpy as np
import pandas as pd
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples=1000, n_classes=2, n_features=20)

# %%
X.shape
# Out:
# (1000, 20)

# %%
y = y.reshape(-1, 1)
y.shape
# Out:
# (1000, 1)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

model.add(Dense(128, activation='relu', input_shape=(20, )))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /Users/aryanahuja/Documents/Aryan/Projects/DL_Prac/env/lib/python3.11/site-packages/keras/src/layers/core/dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)

# %%
history = model.fit(X_train, y_train, epochs=20)
# Out:
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 795us/step - accuracy: 0.8012 - loss: 0.4809
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8975 - loss: 0.2742
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - accuracy: 0.9087 - loss: 0.2223
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 872us/step - accuracy: 0.9125 - loss: 0.1995
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - accuracy: 0.9337 - loss: 0.1705
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 0.9400 - loss: 0.1509
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.9488 - loss: 0.1343
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9600 - loss: 0.1132
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 0.9700 - loss: 0.0957
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 978us/step - accuracy: 0.9737 - loss: 0.0814
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 945us/step - accuracy: 0.9800 - loss: 0.0670
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9900 - loss: 0.0534
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - accuracy: 0.9912 - loss: 0.0485
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9937 - loss: 0.0350
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9950 - loss: 0.0295
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9975 - loss: 0.0238
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9975 - loss: 0.0185
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0138
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0118
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9987 - loss: 0.0109

# %%
model.evaluate(X_test, y_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8350 - loss: 0.7149
# [0.7148889303207397, 0.8349999785423279]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras import regularizers

model = Sequential()

model.add(Dense(128, activation='relu', input_shape=(20, )))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=20)
# Out:
# Epoch 1/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 897us/step - accuracy: 0.7175 - loss: 2.7740
# Epoch 2/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.8737 - loss: 1.9582
# Epoch 3/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - accuracy: 0.8625 - loss: 1.4648
# Epoch 4/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 0.8925 - loss: 1.1001
# Epoch 5/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 0.8888 - loss: 0.8716
# Epoch 6/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - accuracy: 0.8900 - loss: 0.7015
# Epoch 7/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - accuracy: 0.9038 - loss: 0.5891
# Epoch 8/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step - accuracy: 0.8988 - loss: 0.5091
# Epoch 9/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.9050 - loss: 0.4513
# Epoch 10/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 815us/step - accuracy: 0.9125 - loss: 0.4041
# Epoch 11/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step - accuracy: 0.9275 - loss: 0.3626
# Epoch 12/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 844us/step - accuracy: 0.9000 - loss: 0.3511
# Epoch 13/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - accuracy: 0.9137 - loss: 0.3353
# Epoch 14/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 838us/step - accuracy: 0.9125 - loss: 0.3160
# Epoch 15/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.9087 - loss: 0.3067
# Epoch 16/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.9062 - loss: 0.2983
# Epoch 17/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.9000 - loss: 0.2956
# Epoch 18/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step - accuracy: 0.9112 - loss: 0.2737
# Epoch 19/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - accuracy: 0.9200 - loss: 0.2533
# Epoch 20/20
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.9175 - loss: 0.2663

# %%
model.evaluate(X_test, y_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8750 - loss: 0.3591
# [0.35914838314056396, 0.875]

# %%
import matplotlib.pyplot as plt

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.title("Accuracy")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.title("Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
# Out:
# Text(0, 0.5, 'Loss')
